# %% [markdown]
# ## Terminology
#
# Below is a summary of the notation used throughout this notebook:
#
# | Notation | Description | Python Variable |
# |:---------|:------------|:---------------|
# | $a$ | Scalar value |  |
# | $\mathbf{a}$ | Vector (bold) |  |
# | **Regression** |  |  |
# | $\mathbf{x}$ | Training example feature values (Size in 1000 sqft) | `x_train` |
# | $\mathbf{y}$ | Training example targets (Price in 1000s of dollars) | `y_train` |
# | $x^{(i)}$, $y^{(i)}$ | $i$-th training example | `x_i`, `y_i` |
# | $m$ | Number of training examples | `m` |
# | $w$ | Model parameter: weight | `w` |
# | $b$ | Model parameter: bias | `b` |
# | $f_{w,b}(x^{(i)})$ | Model prediction at $x^{(i)}$: $f_{w,b}(x^{(i)}) = wx^{(i)} + b$ | `tmp_f_wb` |
#
# **Current variable values:**
#
# - `x_train = [1.0, 2.0]`
# - `y_train = [300.0, 500.0]`
# - `m = 2`
# - `w = 200`
# - `b = 100`
# - `x_i = 1.2`
# - `y_i = 500.0`
# - `tmp_f_wb = [300.0, 500.0]`
# - `cost_1200sqft = 340.0`

# %%
# %pip install numpy matplotlib
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
# x_train is the input variable (size in 1000 square feet)
# y_train is the target (price in 1000s of dollars)
x_train = np.array([1.0, 2.0])
y_train = np.array([300.0, 500.0])
print(f"x_train = {x_train}")
print(f"y_train = {y_train}")
# Out:
# x_train = [1. 2.]
# y_train = [300. 500.]

# %%
# m is the number of training examples
print(f"x_train.shape: {x_train.shape}")
m = x_train.shape[0]
print(f"Number of training examples is: {m}")
# Out:
# x_train.shape: (2,)
# Number of training examples is: 2

# %%
for i in range(2):
    print(f"x_train[{i}] = {x_train[i]}")
    print(f"y_train[{i}] = {y_train[i]}")
# Out:
# x_train[0] = 1.0
# y_train[0] = 300.0
# x_train[1] = 2.0
# y_train[1] = 500.0

# %%
# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r')
# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.show()

# %%
w = 200
b = 100
print(f"w: {w}")
print(f"b: {b}")
# Out:
# w: 200
# b: 100

# %%
def compute_model_output(x, w, b):
    """
    Computes the prediction of a linear model
    Args:
      x (ndarray (m,)): Data, m examples 
      w,b (scalar)    : model parameters  
    Returns
      f_wb (ndarray (m,)): model prediction
    """
    
    
    f_wb = w*x + b
        
    return f_wb

# %%
tmp_f_wb = compute_model_output(x_train, w, b)

# Plot our model prediction
plt.plot(x_train, tmp_f_wb, c='b',label='Our Prediction')

# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r',label='Actual Values')

# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()

# %%
w = 200                         
b = 100    
x_i = 1.4
cost_1200sqft = w * x_i + b    

print(f"${cost_1200sqft:.0f} thousand dollars")
# Out:
# $380 thousand dollars
